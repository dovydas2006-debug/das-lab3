# %%
import pandas as pd
import random

df_1000 = pd.read_csv(r"C:\Users\Lenovo\Desktop\DAS_lab_3\data\a_steam_data_1000.csv")
df_10000 = pd.read_csv(r"C:\Users\Lenovo\Desktop\DAS_lab_3\data\a_steam_data_10000.csv")
df_50000 = pd.read_csv(r"C:\Users\Lenovo\Desktop\DAS_lab_3\data\a_steam_data_50000.csv")
